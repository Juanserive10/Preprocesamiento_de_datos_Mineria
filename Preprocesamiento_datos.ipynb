# %% [markdown]
# # 1 Portada (Lucas)

# %% [markdown]
# # 2 Resumen Ejecutivo (Lucas)

# %% [markdown]
# # 3 Introducción (Lucas)

# %% [markdown]
# # 4 Descripción del dominio y fuentes (Felipe)

# %% [markdown]
# # 5 Exploración Inicial (Felipe)

# %% [markdown]
# # 6 Caracterización estructural de los datos (Felipe)

# %% [markdown]
# # 7 Diseño del modelo de almacenamiento (con diagrama) (Jhoan)

# %% [markdown]
# # 8 Proceso de preprocesamiento (metodología aplicada) (Jhoan)

# %% [markdown]
# # 9 Analisis descriptivo (Rivera)

# %% [markdown]
# # 10 Resultados del preprocesamiento (Rivera)

# %% [markdown]
# # 11 Reflexión técnica y recomendaciones (Felipe)

# %% [markdown]
# # 12 Conclusiones (Rivera)

# %% [markdown]
# # 13 Referencias (Jhoan)
